# %%
# 1. Investigating the missing data: decide if imputation is possible
# Columns: CARRIER, CARRIER_NAME, MANUFACTURE_YEAR, NUMBER_OF_SEATS, CAPACITY_IN_POUNDS, AIRLINE_ID

# %%
# Specify which version of scipy and seaborn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
# !pip install scikit-learn
from sklearn.impute import SimpleImputer
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
aircraft = pd.read_csv('/content/T_F41SCHEDULE_B43 2.csv')
aircraft.head()
aircraft.info()
# Out:
# <ipython-input-414-5dc6f0bfa6e9>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   aircraft = pd.read_csv('/content/T_F41SCHEDULE_B43 2.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132313 entries, 0 to 132312
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 132313 non-null  int64
#  1   CARRIER              132264 non-null  object
#  2   CARRIER_NAME         132208 non-null  object
#  3   MANUFACTURE_YEAR     132310 non-null  float64
#  4   UNIQUE_CARRIER_NAME  132208 non-null  object
#  5   SERIAL_NUMBER        132313 non-null  object
#  6   TAIL_NUMBER          132313 non-null  object
#  7   AIRCRAFT_STATUS      132313 non-null  object
#  8   OPERATING_STATUS     132313 non-null  object
#  9   NUMBER_OF_SEATS      132306 non-null  float64
#  10  MANUFACTURER         132313 non-null  object
#  11  AIRCRAFT_TYPE        102380 non-null  object
#  12  MODEL                132302 non-null  object
#  13  CAPACITY_IN_POUNDS   132212 non-null  float64
#  14  ACQUISITION_DATE     131346 non-null  object
#  15  AIRLINE_ID           132208 non-null  float64
#  16  UNIQUE_CARRIER       132149 non-null  object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 17.2+ MB

# %% [markdown]
# **Question 1**

# %%
# Making copy of data for imputation/transformation/standardization
aircraft_copy = aircraft.copy()

# %%
# CARRIER

# Printing the rows where the Carrier is missing
aircraft_copy[aircraft_copy['CARRIER'].isnull()]

# Checking what the carrier means: it seems like NaN corresponds to North American Airlines
aircraft_copy[['CARRIER', 'CARRIER_NAME']].drop_duplicates().sort_values('CARRIER')
# Out:
#       CARRIER                                       CARRIER_NAME
# 36306     09Q                                     Swift Air, LLC
# 85907     09Q  Swift Air, LLC d/b/a Eastern Air Lines d/b/a E...
# 22117     0JQ                                    Vision Airlines
# 22144     0WQ                                  Avjet Corporation
# 0          16                                  PSA Airlines Inc.
# ...       ...                                                ...
# 29084     YX                                   Republic Airlines
# 7339       ZQ                             Caribbean Sun Airlines
# 7345       ZW                        Air Wisconsin Airlines Corp
# 29169     ZW                         Air Wisconsin Airlines Corp
# 11776     NaN                            North American Airlines
#
# [204 rows x 2 columns]

# %%
# Number of rows where the carrier name is "North American Airlines"
num_north_american = aircraft_copy[aircraft_copy['CARRIER_NAME'] == 'North American Airlines'].shape[0]

# Number of rows where the carrier name is not "North American Airlines"
print(num_north_american)

# Number of rows where carrier is missing (to see if it matches with the number of north american airlines)
print(aircraft_copy[aircraft_copy['CARRIER'].isnull()].shape[0])
# Out:
# 59
# 49

# %%
# Since there is a mismatch of 10 rows, I am identifying the rows that have North American Airlines as the Carrier Name
# but don't have NaN as the Carrier: NA is also used for North American Airlines
mismatch = aircraft[
    (aircraft['CARRIER_NAME'] == 'North American Airlines') &
    (aircraft['CARRIER'].notnull())
]

mismatch

# Confirmed that all 10 rows that have a missing Carrier are listed as NA with North American Airlines
# print(mismatch.shape[0])
# Out:
#        YEAR CARRIER             CARRIER_NAME  MANUFACTURE_YEAR  \
# 26207  2009     NA   North American Airlines            1993.0
# 26208  2009     NA   North American Airlines            1993.0
# 26209  2009     NA   North American Airlines            1995.0
# 26210  2009     NA   North American Airlines            1996.0
# 26211  2009     NA   North American Airlines            1997.0
# 26212  2009     NA   North American Airlines            2000.0
# 26213  2009     NA   North American Airlines            2001.0
# 26214  2009     NA   North American Airlines            2001.0
# 26215  2009     NA   North American Airlines            2002.0
# 26216  2009     NA   North American Airlines            2002.0
#
#            UNIQUE_CARRIER_NAME    SERIAL_NUMBER      TAIL_NUMBER  \
# 26207  North American Airlines  26257            N760NA
# 26208  North American Airlines  27135            N764NA
# 26209  North American Airlines  26277            N750NA
# 26210  North American Airlines  28098            N765NA
# 26211  North American Airlines  28174            N752NA
# 26212  North American Airlines  30043            N755NA
# 26213  North American Airlines  29381            N754NA
# 26214  North American Airlines  32448            N756NA
# 26215  North American Airlines  27569            N767NA
# 26216  North American Airlines  29898            N768NA
#
#       AIRCRAFT_STATUS OPERATING_STATUS  NUMBER_OF_SEATS  \
# 26207               B                Y            273.0
# 26208               B                Y            252.0
# 26209               B                Y            199.0
# 26210               B                Y            206.0
# 26211               B                Y            199.0
# 26212               B                Y            199.0
# 26213               B                Y            199.0
# 26214               B                Y            199.0
# 26215               B                Y            247.0
# 26216               B                Y            262.0
#
#                                             MANUFACTURER AIRCRAFT_TYPE  \
# 26207  BOEING                                        ...           NaN
# 26208  BOEING                                        ...           NaN
# 26209  BOEING                                        ...           NaN
# 26210  BOEING                                        ...           NaN
# 26211  BOEING                                        ...           NaN
# 26212  BOEING                                        ...           NaN
# 26213  BOEING                                        ...           NaN
# 26214  BOEING                                        ...           NaN
# 26215  BOEING                                        ...           NaN
# 26216  BOEING                                        ...           NaN
#
#                       MODEL  CAPACITY_IN_POUNDS       ACQUISITION_DATE  \
# 26207  B-767-3                         104476.0  3/23/2004 12:00:00 AM
# 26208  B-767-3                         103150.0  2/20/2009 12:00:00 AM
# 26209  B-757-2                          58491.0  1/27/1995 12:00:00 AM
# 26210  B-767-3                          94523.0  3/23/2006 12:00:00 AM
# 26211  B-757-2                          58948.0  5/12/1999 12:00:00 AM
# 26212  B-757-2                          56526.0  2/25/2003 12:00:00 AM
# 26213  B-757-2                          58550.0   4/2/2001 12:00:00 AM
# 26214  B-757-2                          58159.0   6/3/2001 12:00:00 AM
# 26215  B-767-3                         105420.0  8/14/2002 12:00:00 AM
# 26216  B-767-3                         103057.0   9/6/2002 12:00:00 AM
#
#        AIRLINE_ID UNIQUE_CARRIER
# 26207     20415.0            NaN
# 26208     20415.0            NaN
# 26209     20415.0            NaN
# 26210     20415.0            NaN
# 26211     20415.0            NaN
# 26212     20415.0            NaN
# 26213     20415.0            NaN
# 26214     20415.0            NaN
# 26215     20415.0            NaN
# 26216     20415.0            NaN

# %%
# For Carrier, all missing value correspond to North American Airlines. There are also 10 rows for North American
# Airlines that correspond to a Carrier called "NA." Therefore, I am going to use simple imputation with a constant (NA)
# for all the "missing" values currently listed as "NaN."

constant_imputer = SimpleImputer(strategy='constant')
constant_imputer.fill_value = 'NA'

aircraft_copy['CARRIER'] = constant_imputer.fit_transform(aircraft_copy[['CARRIER']]).ravel()

# Confirming that all missing values were filled
print(aircraft_copy['CARRIER'].isnull().sum())
print((aircraft_copy['CARRIER'] == 'NA').sum())
print(aircraft_copy['CARRIER'].unique())
print(aircraft_copy[aircraft_copy['CARRIER_NAME'].str.strip() == 'North American Airlines'].shape[0])

# Still has a mismatch: from the printout, it seems like some of the codes have a space after the carrier
# To standardize the codes, I am going through and removing the space from the end of every carrier
aircraft_copy['CARRIER'] = aircraft_copy['CARRIER'].str.strip()
print(aircraft_copy['CARRIER'].unique())

# Now all of the NaN values are replaced with NA and match the previous code for North American Airlines
print((aircraft_copy['CARRIER'] == 'NA').sum())
# Out:
# 0
# 49
# ['16' '3Z' '5X' '5Y' '8C' '9E' '9S' 'AA' 'ABX' 'AJQ' 'AMQ' 'AQ' 'AS' 'AX'
#  'B6' 'CO' 'CS' 'CTQ' 'DL' 'E0' 'ER' 'EV' 'F2' 'F9' 'FL' 'FX' 'G4' 'G7'
#  'GFQ' 'GG' 'HA' 'HP' 'JW' 'KAQ' 'KLQ' 'L2' 'M6' 'MG' 'MQ' 'MRQ' 'NC' 'NK'
#  'NW' 'OH' 'OO' 'OW' 'PCQ' 'PFQ' 'PO' 'PRQ' 'PT' 'QX' 'RD' 'SI' 'SLQ' 'SY'
#  'TZ' 'U5' 'U7' 'UA' 'US' 'WI' 'WN' 'WO' 'X9' 'XE' 'XJ' 'XP' 'YV' 'YX'
#  'ZQ' 'ZW' 'CP' 'E9' 'EZ' 'FE' 'L4' 'NA' 'RW' 'S5' 'SX' 'VX' 'WE' '9L'
#  'FCQ' 'GL' '0JQ' '0WQ' '16 ' '3Z ' '5X ' '5Y ' '8C ' '9E ' '9L ' '9S '
#  'AA ' 'AQ ' 'AS ' 'B6 ' 'CO ' 'CP ' 'CS ' 'DL ' 'ER ' 'EV ' 'EZ ' 'F9 '
#  'FL ' 'FX ' 'G4 ' 'G7 ' 'GL ' 'HA ' 'JW ' 'L2 ' 'L3 ' 'M6 ' 'MQ ' 'NA '
#  'NC ' 'NK ' 'NW ' 'OH ' 'OO ' 'OW ' 'PM ' 'PO ' 'PT ' 'QX ' 'RD ' 'S5 '
#  'SI ' 'SY ' 'U5 ' 'U7 ' 'UA ' 'US ' 'VX ' 'WE ' 'WI ' 'WN ' 'WO ' 'X9 '
#  'XE ' 'XJ ' 'XP ' 'YV ' 'YX ' 'ZW ' 'KH' 'L3' 'PM' '09Q' '1BQ' '1EQ' 'K8'
#  'RP' '1TQ' '5V' 'WP' '20Q' 'KD' '23Q' '27Q' 'EE' '2HQ' '2PQ' 'N8' '34Q'
#  '37Q' '3EQ' 'WL' 'C5' '3FQ' '3M' 'GCA' 'MX']
# 59
# ['16' '3Z' '5X' '5Y' '8C' '9E' '9S' 'AA' 'ABX' 'AJQ' 'AMQ' 'AQ' 'AS' 'AX'
#  'B6' 'CO' 'CS' 'CTQ' 'DL' 'E0' 'ER' 'EV' 'F2' 'F9' 'FL' 'FX' 'G4' 'G7'
#  'GFQ' 'GG' 'HA' 'HP' 'JW' 'KAQ' 'KLQ' 'L2' 'M6' 'MG' 'MQ' 'MRQ' 'NC' 'NK'
#  'NW' 'OH' 'OO' 'OW' 'PCQ' 'PFQ' 'PO' 'PRQ' 'PT' 'QX' 'RD' 'SI' 'SLQ' 'SY'
#  'TZ' 'U5' 'U7' 'UA' 'US' 'WI' 'WN' 'WO' 'X9' 'XE' 'XJ' 'XP' 'YV' 'YX'
#  'ZQ' 'ZW' 'CP' 'E9' 'EZ' 'FE' 'L4' 'NA' 'RW' 'S5' 'SX' 'VX' 'WE' '9L'
#  'FCQ' 'GL' '0JQ' '0WQ' 'L3' 'PM' 'KH' '09Q' '1BQ' '1EQ' 'K8' 'RP' '1TQ'
#  '5V' 'WP' '20Q' 'KD' '23Q' '27Q' 'EE' '2HQ' '2PQ' 'N8' '34Q' '37Q' '3EQ'
#  'WL' 'C5' '3FQ' '3M' 'GCA' 'MX']
# 59

# %%
# CARRIER_NAME

# Looking at the rows with null Carrier Names: It seems like all rows have valid "Carrier" values. Need to map these values to eachother
aircraft_copy[aircraft_copy['CARRIER_NAME'].isnull()]
# Found that there are 105 rows where the carrier name is missing
# print(aircraft[aircraft['CARRIER_NAME'].isnull()].shape[0])

# Mapping carrier to carrier name
map = aircraft_copy[['CARRIER', 'CARRIER_NAME']].dropna().drop_duplicates()

# Seeing whcih carrier codes have missing carrier_name values: from this only OH and L4 are missing
print(aircraft_copy[aircraft_copy['CARRIER_NAME'].isnull()]['CARRIER'].value_counts())

# Checking to see what Carrier Name OH and L4 map to: from this, I can see that there are two carrier names for the "OH" Carrier
print(aircraft_copy[aircraft_copy['CARRIER'].isin(['OH', 'L4'])][['CARRIER', 'CARRIER_NAME']].drop_duplicates().sort_values('CARRIER'))

# Exporting the rows with OH as a Carrier to inspect what the difference is: found that all the missing values are from 2013
OH_rows = aircraft_copy[aircraft_copy['CARRIER'] == 'OH']
OH_rows.to_csv('OH_carrier_rows.csv', index=False)

# Checking that the number of rows where Carrier Name is missing matches the number of rows where the year is 2013
num_2013 = aircraft_copy[(aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['YEAR'] == 2013)].shape[0]
print("Total number of rows with carrier 'OH' in 2013: ", num_2013)

OH_missing = aircraft_copy[(aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['CARRIER_NAME'].isnull())].shape[0]
print("Number of rows where the Carrier Name is missing and the Carrier is 'OH': ", OH_missing)

OH_2010_2016 = aircraft_copy[(aircraft_copy['YEAR'] >= 2010) & (aircraft_copy['YEAR'] <= 2016) & (aircraft_copy['CARRIER'] == 'OH')]
print(OH_2010_2016[['YEAR', 'CARRIER', 'CARRIER_NAME', 'MODEL']])

OH_2013 = aircraft_copy[(aircraft_copy['YEAR'] == 2013) & (aircraft_copy['CARRIER'] == 'OH')]
print(OH_2013[['YEAR', 'CARRIER', 'CARRIER_NAME', 'MODEL']])

# It appears that the rows that are missing are all in 2013. The years prior to and including 2011 are labeled as Comair Inc., and the years
# after and including 2015 are labeled as PSA Airlines Inc. With further inspection of the data, the model stayed the same from 2011 through 2013
# ("CRJ100-Passanger") and switched to "CRJ701" once the carrier name changed in 2015. Therefore, it seems most likely that the carrier name during
# that year was still Comair Inc.. Simple Imputation with a constant can be used to replace the missing values with Comair Inc.

location = (aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['CARRIER_NAME'].isnull())
aircraft_copy.loc[location, 'CARRIER_NAME'] = 'Comair Inc.'

# Checking that all missing values were filled
print(aircraft_copy['CARRIER_NAME'].isnull().sum())
# Still 8 that haven't been replaced: L4 Carriers

print(aircraft_copy[(aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['YEAR'] == 2013)][['YEAR', 'CARRIER', 'CARRIER_NAME']])
# From this, can see that all the NaN values in 2013 have been cahnged to Comair Inc.
# Out:
# CARRIER
# OH    97
# L4     8
# Name: count, dtype: int64
#       CARRIER                           CARRIER_NAME
# 11465      L4                                    NaN
# 18739      L4  Lynx Aviation d/b/a Frontier Airlines
# 4896       OH                            Comair Inc.
# 54610      OH                                    NaN
# 68915      OH                      PSA Airlines Inc.
# Total number of rows with carrier 'OH' in 2013:  97
# Number of rows where the Carrier Name is missing and the Carrier is 'OH':  97
#        YEAR CARRIER       CARRIER_NAME             MODEL
# 33726  2010      OH        Comair Inc.  CRJ100-Passanger
# 33727  2010      OH        Comair Inc.  CRJ100-Passanger
# 33728  2010      OH        Comair Inc.  CRJ100-Passanger
# 33729  2010      OH        Comair Inc.  CRJ100-Passanger
# 33730  2010      OH        Comair Inc.  CRJ100-Passanger
# ...     ...     ...                ...               ...
# 76153  2016      OH  PSA Airlines Inc.            CRJ900
# 76154  2016      OH  PSA Airlines Inc.            CRJ900
# 76155  2016      OH  PSA Airlines Inc.            CRJ900
# 76156  2016      OH  PSA Airlines Inc.            CRJ900
# 76157  2016      OH  PSA Airlines Inc.            CRJ900
#
# [506 rows x 4 columns]
#        YEAR CARRIER CARRIER_NAME             MODEL
# 54610  2013      OH          NaN  CRJ100-Passanger
# 54611  2013      OH          NaN  CRJ100-Passanger
# 54612  2013      OH          NaN  CRJ100-Passanger
# 54613  2013      OH          NaN  CRJ100-Passanger
# 54614  2013      OH          NaN  CRJ100-Passanger
# ...     ...     ...          ...               ...
# 54702  2013      OH          NaN  CRJ900-Passanger
# 54703  2013      OH          NaN  CRJ900-Passanger
# 54704  2013      OH          NaN  CRJ900-Passanger
# 54705  2013      OH          NaN  CRJ900-Passanger
# 54706  2013      OH          NaN  CRJ900-Passanger
#
# [97 rows x 4 columns]
# 8
#        YEAR CARRIER CARRIER_NAME
# 54610  2013      OH  Comair Inc.
# 54611  2013      OH  Comair Inc.
# 54612  2013      OH  Comair Inc.
# 54613  2013      OH  Comair Inc.
# 54614  2013      OH  Comair Inc.
# ...     ...     ...          ...
# 54702  2013      OH  Comair Inc.
# 54703  2013      OH  Comair Inc.
# 54704  2013      OH  Comair Inc.
# 54705  2013      OH  Comair Inc.
# 54706  2013      OH  Comair Inc.
#
# [97 rows x 3 columns]

# %%
print(aircraft_copy[(aircraft_copy['CARRIER'] == 'L4')][['YEAR', 'CARRIER', 'CARRIER_NAME']])

# As found before, L4 only mapped to one Carrier_Name (Lynx Aviation d/b/a Frontier Airlines), so I am going to use simple imputation with a constant
# for all the "missing" values still listed as "NaN." I will replace all of those values with "Lynx Aviation d/b/a Frontier Airlines"
constant_imputer_L4 = SimpleImputer(strategy='constant')
constant_imputer_L4.fill_value = 'Lynx Aviation d/b/a Frontier Airlines'

aircraft_copy['CARRIER_NAME'] = constant_imputer_L4.fit_transform(aircraft_copy[['CARRIER_NAME']]).ravel()

# Checking that all missing values were filled
print(aircraft_copy['CARRIER_NAME'].isnull().sum())
print(aircraft_copy[(aircraft_copy['CARRIER'] == 'L4')][['YEAR', 'CARRIER', 'CARRIER_NAME']])
# From this, can see that all the NaN values have been changed
# Out:
#        YEAR CARRIER                           CARRIER_NAME
# 11465  2007      L4                                    NaN
# 11466  2007      L4                                    NaN
# 11467  2007      L4                                    NaN
# 11468  2007      L4                                    NaN
# 11469  2007      L4                                    NaN
# 11470  2007      L4                                    NaN
# 11471  2007      L4                                    NaN
# 11472  2007      L4                                    NaN
# 18739  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18740  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18741  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18742  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18743  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18744  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18745  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18746  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18747  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18748  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 0
#        YEAR CARRIER                           CARRIER_NAME
# 11465  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11466  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11467  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11468  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11469  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11470  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11471  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 11472  2007      L4  Lynx Aviation d/b/a Frontier Airlines
# 18739  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18740  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18741  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18742  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18743  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18744  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18745  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18746  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18747  2008      L4  Lynx Aviation d/b/a Frontier Airlines
# 18748  2008      L4  Lynx Aviation d/b/a Frontier Airlines

# %%
# MANUFACTURE_YEAR

# Printing the rows where the MANUFACTURE_YEAR is missing: found that there are only three instances
print(aircraft_copy[aircraft_copy['MANUFACTURE_YEAR'].isnull()])

# Found that the missing values have: (2 are the same, just different serial numbers and tail numbers)
# Manufacturer: BOEING; Model: B747-400
# Manufacturer: BOMBARDIER; Model: CL-600-2C10
# Manufacturer: BOMBARDIER; Model: CL-600-2C10

# Finding other instances where the Manufacturer and Model were used in the dataset to see if the
# year is shown
# Checking BOMBARDIER and CL-600-2C10 First
missing_years = aircraft_copy[(aircraft_copy['MANUFACTURER'] == 'BOMBARDIER') &
          (aircraft['MODEL'] == 'CL-600-2C10')]

print(missing_years)

print(missing_years.shape[0])
# From this, it can be seen that there are 18 other instances where the manufacturer, model, number of seats,
# carrier, and capacity is the same. In these rows, the only years that exist are 2002, 2003, and 2004. Based
# on this, the mode will be used for simple imputation with a constant since the mode will most closely align
# with other very similar aircrafts.
mode = missing_years['MANUFACTURE_YEAR'].mode()[0]
print(mode)

# 2003.0 is the mode: setting those NaN values to 2003.0
aircraft_copy.loc[(aircraft_copy['MODEL'] == 'CL-600-2C10') & (aircraft_copy['MANUFACTURE_YEAR'].isnull()),'MANUFACTURE_YEAR'] = mode
# Out:
#         YEAR CARRIER       CARRIER_NAME  MANUFACTURE_YEAR UNIQUE_CARRIER_NAME  \
# 116651  2022      5Y     Atlas Air Inc.               NaN      Atlas Air Inc.
# 124680  2023      9E  Endeavor Air Inc.               NaN   Endeavor Air Inc.
# 124681  2023      9E  Endeavor Air Inc.               NaN   Endeavor Air Inc.
#
#        SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS OPERATING_STATUS  \
# 116651         26259      N664GT               B                Y
# 124680         10134      N655CA               O                Y
# 124681         10182      N690CA               O                N
#
#         NUMBER_OF_SEATS MANUFACTURER AIRCRAFT_TYPE        MODEL  \
# 116651              0.0       BOEING          8192     B747-400
# 124680             69.0   BOMBARDIER          6311  CL-600-2C10
# 124681             69.0   BOMBARDIER          6311  CL-600-2C10
#
#         CAPACITY_IN_POUNDS       ACQUISITION_DATE  AIRLINE_ID UNIQUE_CARRIER
# 116651                 0.0  1/25/2022 12:00:00 AM     20007.0             5Y
# 124680             18055.0                    NaN     20363.0             9E
# 124681             18055.0                    NaN     20363.0             9E
#         YEAR CARRIER       CARRIER_NAME  MANUFACTURE_YEAR UNIQUE_CARRIER_NAME  \
# 124680  2023      9E  Endeavor Air Inc.               NaN   Endeavor Air Inc.
# 124681  2023      9E  Endeavor Air Inc.               NaN   Endeavor Air Inc.
# 124682  2023      9E  Endeavor Air Inc.            2002.0   Endeavor Air Inc.
# 124683  2023      9E  Endeavor Air Inc.            2002.0   Endeavor Air Inc.
# 124684  2023      9E  Endeavor Air Inc.            2002.0   Endeavor Air Inc.
# 124685  2023      9E  Endeavor Air Inc.            2002.0   Endeavor Air Inc.
# 124686  2023      9E  Endeavor Air Inc.            2002.0   Endeavor Air Inc.
# 124687  2023      9E  Endeavor Air Inc.            2002.0   Endeavor Air Inc.
# 124688  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124689  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124690  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124691  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124692  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124693  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124694  2023      9E  Endeavor Air Inc.            2003.0   Endeavor Air Inc.
# 124695  2023      9E  Endeavor Air Inc.            2004.0   Endeavor Air Inc.
# 124696  2023      9E  Endeavor Air Inc.            2004.0   Endeavor Air Inc.
# 124697  2023      9E  Endeavor Air Inc.            2004.0   Endeavor Air Inc.
#
#        SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS OPERATING_STATUS  \
# 124680         10134      N655CA               O                Y
# 124681         10182      N690CA               O                N
# 124682         10055      N317CA               O                N
# 124683         10061      N331CA               O                N
# 124684         10062      N340CA               O                Y
# 124685         10064      N354CA               O                Y
# 124686         10067      N355CA               O                N
# 124687         10069      N367CA               O                Y
# 124688         10075      N368CA               O                Y
# 124689         10082      N371CA               O                N
# 124690         10092      N376CA               O                Y
# 124691         10102      N379CA               O                N
# 124692         10106      N390CA               O                Y
# 124693         10108      N391CA               O                Y
# 124694         10112      N398CA               O                Y
# 124695         10153      N659CA               O                N
# 124696         10162      N668CA               O                N
# 124697         10176      N669CA               O                N
#
#         NUMBER_OF_SEATS MANUFACTURER AIRCRAFT_TYPE        MODEL  \
# 124680             69.0   BOMBARDIER          6311  CL-600-2C10
# 124681             69.0   BOMBARDIER          6311  CL-600-2C10
# 124682             69.0   BOMBARDIER          6311  CL-600-2C10
# 124683             69.0   BOMBARDIER          6311  CL-600-2C10
# 124684             69.0   BOMBARDIER          6311  CL-600-2C10
# 124685             69.0   BOMBARDIER          6311  CL-600-2C10
# 124686             69.0   BOMBARDIER          6311  CL-600-2C10
# 124687             69.0   BOMBARDIER          6311  CL-600-2C10
# 124688             69.0   BOMBARDIER          6311  CL-600-2C10
# 124689             69.0   BOMBARDIER          6311  CL-600-2C10
# 124690             69.0   BOMBARDIER          6311  CL-600-2C10
# 124691             69.0   BOMBARDIER          6311  CL-600-2C10
# 124692             69.0   BOMBARDIER          6311  CL-600-2C10
# 124693             69.0   BOMBARDIER          6311  CL-600-2C10
# 124694             69.0   BOMBARDIER          6311  CL-600-2C10
# 124695             69.0   BOMBARDIER          6311  CL-600-2C10
# 124696             69.0   BOMBARDIER          6311  CL-600-2C10
# 124697             69.0   BOMBARDIER          6311  CL-600-2C10
#
#         CAPACITY_IN_POUNDS ACQUISITION_DATE  AIRLINE_ID UNIQUE_CARRIER
# 124680             18055.0              NaN     20363.0             9E
# 124681             18055.0              NaN     20363.0             9E
# 124682             18055.0              NaN     20363.0             9E
# 124683             18055.0              NaN     20363.0             9E
# 124684             18055.0              NaN     20363.0             9E
# 124685             18055.0              NaN     20363.0             9E
# 124686             18055.0              NaN     20363.0             9E
# 124687             18055.0              NaN     20363.0             9E
# 124688             18055.0              NaN     20363.0             9E
# 124689             18055.0              NaN     20363.0             9E
# 124690             18055.0              NaN     20363.0             9E
# 124691             18055.0              NaN     20363.0             9E
# 124692             18055.0              NaN     20363.0             9E
# 124693             18055.0              NaN     20363.0             9E
# 124694             18055.0              NaN     20363.0             9E
# 124695             18055.0              NaN     20363.0             9E
# 124696             18055.0              NaN     20363.0             9E
# 124697             18055.0              NaN     20363.0             9E
# 18
# 2003.0

# %%
# Checking the last missing value for MANUFACTURE_YEAR
print(aircraft_copy[aircraft_copy['MANUFACTURE_YEAR'].isnull()])

# Based on the last findings, checking model, aircraft type, and carrier
boeing_missing_year = aircraft_copy[(aircraft_copy['MANUFACTURER'] == 'BOEING') &
          (aircraft['MODEL'] == 'B747-400') & (aircraft_copy['CARRIER_NAME'] == 'Atlas Air Inc.')]

boeing_missing_year

# There are 283 rows with the same model, aircraft type, and carrier. From this, the aircraft type and capacity look the same.
# The mode will be used again for imputation since it represents the most common and therefore most likely manufacture year for this
# aircraft.
boeing_mode = boeing_missing_year['MANUFACTURE_YEAR'].mode()[0]
print(boeing_mode)

# Using 1998:
aircraft_copy.loc[(aircraft_copy['MODEL'] == 'B747-400') & (aircraft_copy['MANUFACTURE_YEAR'].isnull()),'MANUFACTURE_YEAR'] = boeing_mode
# Out:
#         YEAR CARRIER    CARRIER_NAME  MANUFACTURE_YEAR UNIQUE_CARRIER_NAME  \
# 116651  2022      5Y  Atlas Air Inc.               NaN      Atlas Air Inc.
#
#        SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS OPERATING_STATUS  \
# 116651         26259      N664GT               B                Y
#
#         NUMBER_OF_SEATS MANUFACTURER AIRCRAFT_TYPE     MODEL  \
# 116651              0.0       BOEING          8192  B747-400
#
#         CAPACITY_IN_POUNDS       ACQUISITION_DATE  AIRLINE_ID UNIQUE_CARRIER
# 116651                 0.0  1/25/2022 12:00:00 AM     20007.0             5Y
# 1998.0

# %%
# NUMBER_OF_SEATS

# Printing the rows where the NUMBER_OF_SEATS is missing: found that there are seven instances
aircraft_copy[aircraft_copy['NUMBER_OF_SEATS'].isnull()]
# Found that all missing values have the same manufacturer (Boeing)
# Models: 767-232SFCARGO, 767-338ERCARGO, 767-323ERCARGO
# Aircraft types: 6252 (1), 6262(6)

# Filtering by manufacturer, carrier name, and aircraft type for type 6252: found that the other seats are all 0.0
print(aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'BOEING') &
    (aircraft_copy['AIRCRAFT_TYPE'] == '6252') &
    (aircraft_copy['CARRIER_NAME'] == 'Amerijet International')])

# Filtering by manufacturer, carrier name, and aircraft type for type 6262: again, found that all other seats are 0.0
# (makes sense because the model has CARGO in the name, whihch wouldn't have passenger seats)
print(aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'BOEING') &
    (aircraft_copy['AIRCRAFT_TYPE'] == '6262') &
    (aircraft_copy['CARRIER_NAME'] == 'Amerijet International')][['MANUFACTURER', 'AIRCRAFT_TYPE', 'CARRIER_NAME', 'NUMBER_OF_SEATS']])

# All rows with missing values in 'NUMBER_OF_SEATS' correspond to the same manufacturer and carrier name with two different model types. When grouping by these values, all
# other similar aircrafts have a seat number of 0.0, so simple imputation with a constant of '0.0' can be used for all missing values.
constant_imputer_seats = SimpleImputer(strategy='constant')
constant_imputer_seats.fill_value = 0.0

aircraft_copy['NUMBER_OF_SEATS'] = constant_imputer_seats.fit_transform(aircraft_copy[['NUMBER_OF_SEATS']])

# Checking that all null values are filled:
print(aircraft_copy[aircraft_copy['NUMBER_OF_SEATS'].isnull()].shape[0])
# Out:
#         YEAR CARRIER            CARRIER_NAME  MANUFACTURE_YEAR  \
# 105016  2020      M6  Amerijet International            1982.0
# 112741  2021      M6  Amerijet International            1982.0
# 120803  2022      M6  Amerijet International            1982.0
#
#            UNIQUE_CARRIER_NAME SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS  \
# 105016  Amerijet International         22218      N743AX               b
# 112741  Amerijet International         22218      N743AX               b
# 120803  Amerijet International         22218      N743AX               b
#
#        OPERATING_STATUS  NUMBER_OF_SEATS MANUFACTURER AIRCRAFT_TYPE  \
# 105016                Y              0.0       BOEING          6252
# 112741                Y              0.0       BOEING          6252
# 120803                Y              0.0       BOEING          6252
#
#                  MODEL  CAPACITY_IN_POUNDS      ACQUISITION_DATE  AIRLINE_ID  \
# 105016  767-232SFCARGO             96000.0  7/1/2010 12:00:00 AM     20151.0
# 112741  767-232SFCARGO             96000.0  7/1/2010 12:00:00 AM     20151.0
# 120803  767-232SFCARGO             96000.0  7/1/2010 12:00:00 AM     20151.0
#
#        UNIQUE_CARRIER
# 105016             M6
# 112741             M6
# 120803             M6
#        MANUFACTURER AIRCRAFT_TYPE            CARRIER_NAME  NUMBER_OF_SEATS
# 105017       BOEING          6262  Amerijet International              0.0
# 105018       BOEING          6262  Amerijet International              0.0
# 105019       BOEING          6262  Amerijet International              0.0
# 105020       BOEING          6262  Amerijet International              0.0
# 105021       BOEING          6262  Amerijet International              0.0
# 105022       BOEING          6262  Amerijet International              0.0
# 105023       BOEING          6262  Amerijet International              0.0
# 112742       BOEING          6262  Amerijet International              0.0
# 112743       BOEING          6262  Amerijet International              0.0
# 112744       BOEING          6262  Amerijet International              0.0
# 112745       BOEING          6262  Amerijet International              0.0
# 112746       BOEING          6262  Amerijet International              0.0
# 112747       BOEING          6262  Amerijet International              0.0
# 112748       BOEING          6262  Amerijet International              0.0
# 112749       BOEING          6262  Amerijet International              0.0
# 120804       BOEING          6262  Amerijet International              0.0
# 120805       BOEING          6262  Amerijet International              0.0
# 120806       BOEING          6262  Amerijet International              0.0
# 120807       BOEING          6262  Amerijet International              0.0
# 120808       BOEING          6262  Amerijet International              0.0
# 120809       BOEING          6262  Amerijet International              0.0
# 120812       BOEING          6262  Amerijet International              0.0
# 120813       BOEING          6262  Amerijet International              0.0
# 128685       BOEING          6262  Amerijet International              0.0
# 128686       BOEING          6262  Amerijet International              0.0
# 128687       BOEING          6262  Amerijet International              0.0
# 128688       BOEING          6262  Amerijet International              0.0
# 128689       BOEING          6262  Amerijet International              0.0
# 128690       BOEING          6262  Amerijet International              0.0
# 128693       BOEING          6262  Amerijet International              0.0
# 128694       BOEING          6262  Amerijet International              0.0
# 128695       BOEING          6262  Amerijet International              0.0
# 128696       BOEING          6262  Amerijet International              0.0
# 0

# %%
# CAPACITY_IN_POUNDS

# Printing the rows where the CAPACITY_IN_POUNDS is missing: found that there are 101 instances
print(aircraft_copy[aircraft_copy['CAPACITY_IN_POUNDS'].isnull()])

# Capacity is related to the aircraft_type, manufacturer, and model:
# Looking at the unique manufacturer and aircraft types that have missing capacity
print(aircraft_copy[aircraft_copy['CAPACITY_IN_POUNDS'].isnull()][['MANUFACTURER', 'AIRCRAFT_TYPE', 'MODEL']].drop_duplicates())

# RESULTS for reference
#            MANUFACTURER AIRCRAFT_TYPE          MODEL
# 78991            BOEING          6251       B767-200
# 79015            BOEING          6262       B767-300
# 81902  MCDONNELLDOUGLAS          7302       DC-10-10
# 81910  MCDONNELLDOUGLAS          7322       DC-10-30
# 82224  MCDONNELLDOUGLAS          7402          MD-11
# 90567  AirbusIndustries          7221  A-320-PSGRneo

# Looking at what typical capacity values are for each aircraft type
# Looking at 6251 (BOEING)
capacity_6251 = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'BOEING') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 6251) &
    (aircraft_copy['MODEL'] == 'B767-200')
].dropna().drop_duplicates().sort_values(by='CAPACITY_IN_POUNDS')

# print(capacity_6251)

# Three of the four capacity values are around the same, but there is an outlier of 0.0. Therefore, I will use the median capacity
# in pounds so that any outliers don't affect the result. This best reflects the expected capacity of the aircraft
# given the specific mode, manufacturer, and aircraft type.

median_6251 = capacity_6251['CAPACITY_IN_POUNDS'].median()
print(median_6251)

# Using the median for imputation
aircraft_copy.loc[
    (aircraft_copy['MANUFACTURER'] == 'BOEING') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 6251) &
    (aircraft_copy['MODEL'] == 'B767-200') &
    (aircraft_copy['CAPACITY_IN_POUNDS'].isnull()),
    'CAPACITY_IN_POUNDS'] = median_6251
# Out:
#        YEAR CARRIER                 CARRIER_NAME  MANUFACTURE_YEAR  \
# 78991  2017      5Y               Atlas Air Inc.            1982.0
# 79015  2017      5Y               Atlas Air Inc.            2012.0
# 79016  2017      5Y               Atlas Air Inc.            2012.0
# 81902  2017      FX  Federal Express Corporation            1971.0
# 81903  2017      FX  Federal Express Corporation            1971.0
# ...     ...     ...                          ...               ...
# 82456  2017      FX  Federal Express Corporation            1999.0
# 82457  2017      FX  Federal Express Corporation            1999.0
# 82458  2017      FX  Federal Express Corporation            1999.0
# 90567  2018      NK             Spirit Air Lines            2018.0
# 90569  2018      NK             Spirit Air Lines            2018.0
#
#                UNIQUE_CARRIER_NAME SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS  \
# 78991               Atlas Air Inc.         22694      N767MW               b
# 79015               Atlas Air Inc.         37809      N643GT               b
# 79016               Atlas Air Inc.         37810      N644GT               b
# 81902  Federal Express Corporation         46601      N365FE               O
# 81903  Federal Express Corporation         46606      N368FE               O
# ...                            ...           ...         ...             ...
# 82456  Federal Express Corporation         48791      N620FE               b
# 82457  Federal Express Corporation         48792      N621FE               b
# 82458  Federal Express Corporation         48794      N623FE               b
# 90567             Spirit Air Lines          8658      N908NK               b
# 90569             Spirit Air Lines          8668      N910NK               b
#
#       OPERATING_STATUS  NUMBER_OF_SEATS      MANUFACTURER AIRCRAFT_TYPE  \
# 78991                Y            181.0            BOEING          6251
# 79015                Y              0.0            BOEING          6262
# 79016                Y              0.0            BOEING          6262
# 81902                Y              0.0  MCDONNELLDOUGLAS          7302
# 81903                Y              0.0  MCDONNELLDOUGLAS          7302
# ...                ...              ...               ...           ...
# 82456                Y              0.0  MCDONNELLDOUGLAS          7402
# 82457                Y              0.0  MCDONNELLDOUGLAS          7402
# 82458                Y              0.0  MCDONNELLDOUGLAS          7402
# 90567                Y            182.0  AirbusIndustries          7221
# 90569                Y            182.0  AirbusIndustries          7221
#
#                MODEL  CAPACITY_IN_POUNDS        ACQUISITION_DATE  AIRLINE_ID  \
# 78991       B767-200                 NaN    7/1/2013 12:00:00 AM     20007.0
# 79015       B767-300                 NaN   1/17/2013 12:00:00 AM     20007.0
# 79016       B767-300                 NaN   1/22/2013 12:00:00 AM     20007.0
# 81902       DC-10-10                 NaN   11/6/1997 12:00:00 AM     20107.0
# 81903       DC-10-10                 NaN   8/21/1997 12:00:00 AM     20107.0
# ...              ...                 ...                     ...         ...
# 82456          MD-11                 NaN   3/25/1999 12:00:00 AM     20107.0
# 82457          MD-11                 NaN   5/28/1999 12:00:00 AM     20107.0
# 82458          MD-11                 NaN   6/28/1999 12:00:00 AM     20107.0
# 90567  A-320-PSGRneo                 NaN  12/17/2018 12:00:00 AM     20416.0
# 90569  A-320-PSGRneo                 NaN  12/20/2018 12:00:00 AM     20416.0
#
#       UNIQUE_CARRIER
# 78991             5Y
# 79015             5Y
# 79016             5Y
# 81902             FX
# 81903             FX
# ...              ...
# 82456             FX
# 82457             FX
# 82458             FX
# 90567             NK
# 90569             NK
#
# [101 rows x 17 columns]
#            MANUFACTURER AIRCRAFT_TYPE          MODEL
# 78991            BOEING          6251       B767-200
# 79015            BOEING          6262       B767-300
# 81902  MCDONNELLDOUGLAS          7302       DC-10-10
# 81910  MCDONNELLDOUGLAS          7322       DC-10-30
# 82224  MCDONNELLDOUGLAS          7402          MD-11
# 90567  AirbusIndustries          7221  A-320-PSGRneo
# 225573.0

# %%
# Continuing for the remaining aircraft types

# 79015            BOEING          6262       B767-300

# Looking at 6262 (BOEING)
capacity_6262 = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'BOEING') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 6262) &
    (aircraft_copy['MODEL'] == 'B767-300')
].dropna().drop_duplicates().sort_values(by='CAPACITY_IN_POUNDS')

print(capacity_6262)

# In this case, the capacity is the same for both of the aircrafts of the same manufacturer, aircraft_type, and model.
# This will be imputed for the missing value (237756.0)

aircraft_copy.loc[
    (aircraft_copy['MANUFACTURER'] == 'BOEING') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 6262) &
    (aircraft_copy['MODEL'] == 'B767-300') &
    (aircraft_copy['CAPACITY_IN_POUNDS'].isnull()),
    'CAPACITY_IN_POUNDS'] = 237756.0
# Out:
#        YEAR CARRIER    CARRIER_NAME  MANUFACTURE_YEAR UNIQUE_CARRIER_NAME  \
# 71855  2016      5Y  Atlas Air Inc.            2012.0      Atlas Air Inc.
# 71856  2016      5Y  Atlas Air Inc.            2012.0      Atlas Air Inc.
#
#       SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS OPERATING_STATUS  \
# 71855         37809      N643GT               b                Y
# 71856         37810      N644GT               b                Y
#
#        NUMBER_OF_SEATS MANUFACTURER AIRCRAFT_TYPE     MODEL  \
# 71855              0.0       BOEING          6262  B767-300
# 71856              0.0       BOEING          6262  B767-300
#
#        CAPACITY_IN_POUNDS       ACQUISITION_DATE  AIRLINE_ID UNIQUE_CARRIER
# 71855            237756.0  1/17/2013 12:00:00 AM     20007.0             5Y
# 71856            237756.0  1/22/2013 12:00:00 AM     20007.0             5Y

# %%
# 81902  MCDONNELLDOUGLAS          7302       DC-10-10
capacity_7302 = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'MCDONNELLDOUGLAS') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7302) &
    (aircraft_copy['MODEL'] == 'DC-10-10')
].dropna().drop_duplicates().sort_values(by='CAPACITY_IN_POUNDS')

print(capacity_7302[['MANUFACTURER', 'AIRCRAFT_TYPE', 'MODEL', 'CAPACITY_IN_POUNDS']])
# In this case, it makes sense to use the median capacity again because there is a range of values for the given manufacturer,
# aircraft type, and model.

median_7302 = capacity_7302['CAPACITY_IN_POUNDS'].median()
print(median_7302)

# Using the median for imputation
aircraft_copy.loc[
    (aircraft_copy['MANUFACTURER'] == 'MCDONNELLDOUGLAS') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7302) &
    (aircraft_copy['MODEL'] == 'DC-10-10') &
    (aircraft_copy['CAPACITY_IN_POUNDS'].isnull()),
    'CAPACITY_IN_POUNDS'] = median_7302

# Since median imputation was appropriate for the previous aircrafts, I am applying the same method to the
# remaining three, assuming it will also be reasonable given the manufacturer, aircraft type, and model.

# 81910  MCDONNELLDOUGLAS          7322       DC-10-30
capacity_7322 = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'MCDONNELLDOUGLAS') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7322) &
    (aircraft_copy['MODEL'] == 'DC-10-30')
].dropna().drop_duplicates().sort_values(by='CAPACITY_IN_POUNDS')

median_7322 = capacity_7322['CAPACITY_IN_POUNDS'].median()
print(median_7322)

# Using the median for imputation
aircraft_copy.loc[
    (aircraft_copy['MANUFACTURER'] == 'MCDONNELLDOUGLAS') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7322) &
    (aircraft_copy['MODEL'] == 'DC-10-30') &
    (aircraft_copy['CAPACITY_IN_POUNDS'].isnull()),
    'CAPACITY_IN_POUNDS'] = median_7322


# 82224  MCDONNELLDOUGLAS          7402          MD-11
capacity_7402 = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'MCDONNELLDOUGLAS') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7402) &
    (aircraft_copy['MODEL'] == 'MD-11')
].dropna().drop_duplicates().sort_values(by='CAPACITY_IN_POUNDS')

median_7402 = capacity_7402['CAPACITY_IN_POUNDS'].median()
print(median_7402)

# Using the median for imputation
aircraft_copy.loc[
    (aircraft_copy['MANUFACTURER'] == 'MCDONNELLDOUGLAS') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7402) &
    (aircraft_copy['MODEL'] == 'MD-11') &
    (aircraft_copy['CAPACITY_IN_POUNDS'].isnull()),
    'CAPACITY_IN_POUNDS'] = median_7402

# 90567  AirbusIndustries          7221  A-320-PSGRneo
capacity_7221 = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'AirbusIndustries') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7221) &
    (aircraft_copy['MODEL'] == 'A-320-PSGRneo')
].dropna().drop_duplicates().sort_values(by='CAPACITY_IN_POUNDS')

median_7221 = capacity_7221['CAPACITY_IN_POUNDS'].median()
print(median_7221)

# Using the median for imputation
aircraft_copy.loc[
    (aircraft_copy['MANUFACTURER'] == 'AirbusIndustries') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 7221) &
    (aircraft_copy['MODEL'] == 'A-320-PSGRneo') &
    (aircraft_copy['CAPACITY_IN_POUNDS'].isnull()),
    'CAPACITY_IN_POUNDS'] = median_7221
# Out:
#            MANUFACTURER AIRCRAFT_TYPE     MODEL  CAPACITY_IN_POUNDS
# 60419  MCDONNELLDOUGLAS          7302  DC-10-10            135592.0
# 32525  MCDONNELLDOUGLAS        7302.0  DC-10-10            135592.0
# 53470  MCDONNELLDOUGLAS          7302  DC-10-10            135592.0
# 39566  MCDONNELLDOUGLAS          7302  DC-10-10            135592.0
# 32524  MCDONNELLDOUGLAS        7302.0  DC-10-10            135918.0
# ...                 ...           ...       ...                 ...
# 32518  MCDONNELLDOUGLAS        7302.0  DC-10-10            140426.0
# 39536  MCDONNELLDOUGLAS          7302  DC-10-10            140839.0
# 53447  MCDONNELLDOUGLAS          7302  DC-10-10            140839.0
# 60391  MCDONNELLDOUGLAS          7302  DC-10-10            140839.0
# 32494  MCDONNELLDOUGLAS        7302.0  DC-10-10            140839.0
#
# [279 rows x 4 columns]
# 137907.0
# 163122.0
# 192807.0
# 35600.0

# %%
# AIRLINE_ID

# Printing the rows where the CAPACITY_IN_POUNDS is missing: found that the missing values for AIRLINE_ID are the same as the values missing for CARRIER_NAME
aircraft_copy[aircraft_copy['AIRLINE_ID'].isnull()]

# Checking that there are the same numbers of values for missing AIRLINE_ID and CARRIER_NAME: Found that both have 105 rows
print(aircraft_copy[aircraft_copy['AIRLINE_ID'].isnull()][['CARRIER', 'CARRIER_NAME', 'AIRLINE_ID']].sort_values('CARRIER_NAME').shape[0])
print(aircraft[aircraft['CARRIER_NAME'].isnull()].shape[0])

# Checking the unique carriers for the missing airline_ids
aircraft_copy[aircraft_copy['AIRLINE_ID'].isnull()][['CARRIER', 'CARRIER_NAME', 'AIRLINE_ID']].sort_values('AIRLINE_ID').drop_duplicates()
# Confirms that only L4 and OH have missing Airline IDs

# Using the same approach as CARRIER_NAME:
# Checking to see what AIRLINE_ID OH and L4 map to:
print(aircraft_copy[aircraft_copy['CARRIER'].isin(['OH', 'L4'])][['CARRIER', 'CARRIER_NAME', 'AIRLINE_ID']].drop_duplicates().sort_values('AIRLINE_ID'))

# Checking that the number of rows where Carrier Name is missing matches the number of rows where the year is 2013
num_missing_2013 = aircraft_copy[(aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['YEAR'] == 2013)].shape[0]
print("Total number of rows with carrier 'OH' in 2013: ", num_2013)

OH_missing = aircraft_copy[(aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['AIRLINE_ID'].isnull())].shape[0]
print("Number of rows where the Carrier Name is missing and the Carrier is 'OH': ", OH_missing)

# It appears that the rows that are missing the Airline ID are all in 2013, indicating that they are the same values that were missing for
# the carrier name. The years prior to and including 2011 are labeled as 20417.0, and the years after and including 2015 are labeled as 20397.0
# for Airline_ID. From the previous inspection of the data, since the model stayed the same from 2011 through 2013 and changed in 2015 when the carrier name/airline ID
# changed, it seems likely that the airline ID was the same as before 2011 (21217.0). Therefore, simple imputation with a constant is used
# to replace the missing value

missing_airline_id_oh = (aircraft_copy['CARRIER'] == 'OH') & (aircraft_copy['AIRLINE_ID'].isnull())
aircraft_copy.loc[missing_airline_id_oh, 'AIRLINE_ID'] = 20417.0

# From before, L4 only mapped to one Airline_ID (21217.0), so I am going to use simple imputation with a constant
# for all the "missing" values currently listed as "NaN" with the L4 Carrier. I will replace all of those values with 21217.0.

missing_airline_id_l4 = (aircraft_copy['CARRIER'] == 'L4') & (aircraft_copy['AIRLINE_ID'].isnull())
aircraft_copy.loc[missing_airline_id_l4, 'AIRLINE_ID'] = 21217.0
# Out:
# 105
# 105
#       CARRIER                           CARRIER_NAME  AIRLINE_ID
# 68915      OH                      PSA Airlines Inc.     20397.0
# 4896       OH                            Comair Inc.     20417.0
# 18739      L4  Lynx Aviation d/b/a Frontier Airlines     21217.0
# 11465      L4  Lynx Aviation d/b/a Frontier Airlines         NaN
# 54610      OH                            Comair Inc.         NaN
# Total number of rows with carrier 'OH' in 2013:  97
# Number of rows where the Carrier Name is missing and the Carrier is 'OH':  97

# %% [markdown]
# **Question 2**

# %%
# MANUFACTURER

# Transformation is needed because manufacturer names come with case differences and inconsistences
# with naming convention, which would affect later analysis.

# Can already see that there are names that are duplicated because there are manufacturers that say both "BOEING" and "Boeing"
# Originally has 183 manufacturers
print(aircraft_copy['MANUFACTURER'].value_counts())

# Making everything uppercase to normalize the cases (solves casing and whitespace issues)
# Now has 134 manufacturers listed
aircraft_copy['MANUFACTURER'] = aircraft_copy['MANUFACTURER'].str.upper().str.strip()
manufacturer_counts = aircraft_copy['MANUFACTURER'].value_counts()
print(manufacturer_counts)

manufacturer_counts.to_csv('manufacturer_counts.csv', index=True)

# Can see duplicates with the name (ex. BOEING, BOEINGCO, BOEINGCOMPANY, etc.)

# Looking in alphabetical order to help identify dupliates:
aircraft_copy['MANUFACTURER'].sort_values().unique()

# Searching all names that include "BOEING", "AIRBUS"
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('BOEING'),'MANUFACTURER'] = 'BOEING'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('AIRBUS'),'MANUFACTURER'] = 'AIRBUS'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('DOUGLAS'),'MANUFACTURER'] = 'MCDONNELL-DOUGLAS'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('MCDO'),'MANUFACTURER'] = 'MCDONNELL-DOUGLAS'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('BOMBARDIER'),'MANUFACTURER'] = 'BOMBARDIER'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('GULFSTREAM'),'MANUFACTURER'] = 'GULFSTREAM'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('LEAR'),'MANUFACTURER'] = 'LEAR'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('SAAB'),'MANUFACTURER'] = 'SAAB'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('FOKKER'),'MANUFACTURER'] = 'FOKKER'
aircraft_copy.loc[aircraft_copy['MANUFACTURER'].str.contains('DASSAULT'),'MANUFACTURER'] = 'DASSAULT'


# The following seem like typos
aircraft_copy['MANUFACTURER'] = aircraft_copy['MANUFACTURER'].replace({
    'RAETHEON': 'RAYTHEON',
    'FGLAIRCAFT/PEACH': 'FGLAIRCRAFT/PEACH'})

aircraft_copy['MANUFACTURER'].sort_values().unique()

print(aircraft_copy['MANUFACTURER'].value_counts().shape[0])
# Now there are 94 manufacturers listed
# Out:
# MANUFACTURER
# BOEING                        15922
# Embraer                       11508
# THEBOEINGCO                    9223
# Bombardier                     8871
# Boeing                         8392
#                               ...
# BEECHHAWKER400XP                  1
# Dassault-Falcon-2000EXEASy        1
# ISRAELAIRCRAFTINDUSTRIES          1
# JPLEASE/CEBUPACIFIC               1
# JSA/Peach                         1
# Name: count, Length: 183, dtype: int64
# MANUFACTURER
# BOEING                        27159
# EMBRAER                       15554
# AIRBUS                        13440
# BOMBARDIER                    11834
# THEBOEINGCO                    9231
#                               ...
# ROLLS-ROYCE                       1
# MCDONNEL                          1
# DASSAULT-FALCON-2000EXEASY        1
# ISRAELAIRCRAFTINDUSTRIES          1
# JSA/PEACH                         1
# Name: count, Length: 134, dtype: int64
# 94

# %%
# MODEL

print(aircraft_copy['MODEL'].value_counts())
# Originally 1340 Models

aircraft_copy['MODEL'] = aircraft_copy['MODEL'].str.upper().str.strip()
model_counts = aircraft_copy['MODEL'].value_counts()
print(model_counts)
# Now has 1268 models listed

# Looking in alphabetical order to help identify dupliates:
print(aircraft_copy['MODEL'].sort_values().unique()[:1000])

aircraft_copy.loc[aircraft_copy['MODEL'].str.contains('737-700', na=False), 'MODEL'] = '737-700'
# Out:
# MODEL
# EMB-145          2614
# B-737-7H4        2470
# B737-823         2370
# A320-232         2333
# A321-231         2259
#                  ...
# A321-231(P2F)       1
# 777FFX              1
# T210N               1
# 757-29J             1
# 757-260PF           1
# Name: count, Length: 1340, dtype: int64
# MODEL
# EMB-145      2976
# B-737-7H4    2470
# B737-823     2370
# A320-232     2333
# A321-231     2259
#              ...
# MD-9030         1
# 777FFX          1
# 747-48EF        1
# 747-47UF        1
# WESTWINDI       1
# Name: count, Length: 1268, dtype: int64
# ['0' '150' '200' '2012' '208B' '318-111' '319-111' '319-112' '320-112'
#  '320-114' '320-211' '320-211N' '320-214' '320-251' '320-251N' '321-211'
#  '321-271NX' '340BPSGR' '382G-44K-30' '408' '450' '550' '560XL' '600'
#  '601' '601-1A' '6011A' '604' '604/605' '65' '717-200' '717-200-PSGR'
#  '717-200PASSENGERONLY' '717-23S' '717231' '7172BD' '727-200'
#  '727-200CARGO' '727-200F' '727-212CARGO' '727-223' '727-224' '727-225'
#  '727-231ACARGO' '727-232' '727-233ACARGO' '727-264' '727-277-CARGO'
#  '727-281-CARGO' '727-2B6' '727-2F9CARGO' '727-2H3' '727-2M7'
#  '727-2S2F-CARGO' '727225-CARGO' '72722C-CARGO' '727277-CARGO' '737-200'
#  '737-200C' '737-200CARGO' '737-205' '737-2H4' '737-300'
#  '737-300PASSENGERONLY' '737-300SF' '737-301' '737-301F' '737-306'
#  '737-319' '737-330' '737-3B7' '737-3H4' '737-3Y0' '737-400'
#  '737-400-PSGR' '737-401' '737-402' '737-403' '737-404' '737-405'
#  '737-436' '737-45D' '737-484' '737-48E' '737-490' '737-4B7' '737-4C9'
#  '737-4H6' '737-4Q3' '737-4Q8' '737-4YO' '737-500' '737-500PASSENGERONLY'
#  '737-528' '737-59D' '737-700' '737-700-PSGR' '737-700PASSENGERONLY'
#  '737-71B' '737-71Q' '737-724' '737-732' '737-732-PSGR' '737-73V'
#  '737-752' '737-75V' '737-76N' '737-76Q' '737-790' '737-79L' '737-79P'
#  '737-7BD' '737-7BK' '737-7BX' '737-7CG' '737-7CT' '737-7H4' '737-7K5'
#  '737-7K9' '737-7L9' '737-7Q8' '737-7V3' '737-8' '737-800' '737-800-PSGR'
#  '737-800PASSENGERONLY' '737-800SF' '737-808' '737-823' '737-824'
#  '737-82R' '737-832' '737-832-PSGR' '737-83N' '737-84P' '737-86J'
#  '737-86N' '737-8AL' '737-8AS' '737-8BK' '737-8CX' '737-8EH'
#  '737-8EH-PSGR' '737-8F2' '737-8FH' '737-8H4' '737-8JP' '737-8K5'
#  '737-8KN' '737-8Q8' '737-9' '737-900ER' '737-900ER-PSGR' '737-924'
#  '737-924ER' '737-932ER' '737-932ER-PSGR' '737-9GPER' '737NG7H4/W'
#  '747-121' '747-121SCD' '747-122' '747-123BF' '747-123F' '747-132' '747-2'
#  '747-2-2' '747-200' '747-200F' '747-209B' '747-212B' '747-212F'
#  '747-221F' '747-222B' '747-230SF' '747-246B' '747-246F' '747-251B'
#  '747-259B' '747-273C' '747-2B4B' '747-4' '747-400' '747-400-PSGR'
#  '747-400BDSF' '747-400ERF' '747-400F' '747-400M' '747-400SF' '747-412'
#  '747-412BCF' '747-412F' '747-428' '747-428BCF' '747-428F' '747-446'
#  '747-446BCF' '747-44AF' '747-451' '747-451-PSGR' '747-45E' '747-47UF'
#  '747-481F' '747-485F' '747-48EF' '747-4B5' '747-4B5F' '747-4H6'
#  '747-4HAF' '747-4HQF' '747-4R7F' '747-8F' '747-SR46' '747481F' '747CARGO'
#  '750' '7500' '757' '757-200' '757-200-PSGR' '757-200SERIES' '757-204'
#  '757-212-PSGR' '757-21B' '757-222' '757-223' '757-223ERCARGO' '757-224'
#  '757-225' '757-230' '757-230ER' '757-231' '757-231-PSGR' '757-232'
#  '757-232-PSGR' '757-236' '757-23A' '757-24APF' '757-251' '757-251-PSGR'
#  '757-256' '757-256ERCARGO' '757-258' '757-260PF' '757-26D' '757-26D-PSGR'
#  '757-27B' '757-28A' '757-29J' '757-2B7' '757-2G5' '757-2Q8'
#  '757-2Q8-PSGR' '757-2S7' '757-2T7' '757-2Y0' '757-2YO' '757-2Z0'
#  '757-300' '757-300-PSGR' '757-324' '757-33N' '757-351' '757-351-PSGR'
#  '767' '767-200' '767-200/ER' '767-223' '767-223/CARGO' '767-224'
#  '767-232' '767-232/CARGO' '767-232SFCARGO' '767-238' '767-277' '767-281'
#  '767-300' '767-300-PSGR' '767-300/ER' '767-300BCF' '767-300ER'
#  '767-300ER-PSGR' '767-300F' '767-304' '767-304(ER)' '767-316' '767-316F'
#  '767-319' '767-322' '767-323' '767-323ER' '767-323ERCARGO' '767-324'
#  '767-324ER-PSGR' '767-328' '767-32LF' '767-332' '767-332-PSGR'
#  '767-332ER-PSGR' '767-333' '767-338' '767-338ERCARGO' '767-33A' '767-341'
#  '767-341(ER)' '767-341ER' '767-346' '767-34AF' '767-36N' '767-381'
#  '767-3CB' '767-3P6' '767-3P6(ER)' '767-3P6ER-PSGR' '767-3Q8' '767-3S2F'
#  '767-400ER' '767-400ER-PSGR' '767-424ER' '767-432ER' '767-432ER-PSGR'
#  '767-490' '777' '777-200' '777-200-PSGR' '777-222' '777-223' '777-224'
#  '777-232ER-PSGR' '777-232LR' '777-232LR-PSGR' '777-2U8' '777-300ER'
#  '777-323ER' '777-F1H' '777-F28' '777-FHT' '777-FS2' '777F' '777F16'
#  '777F1H' '777F28' '777FFX' '777FHT' '777FZB' '787-10' '787-8' '787-9'
#  '800XP' '850XP' 'A-300' 'A-300-600' 'A-310' 'A-310-200' 'A-310200'
#  'A-318-112PSGR' 'A-319' 'A-319-1' 'A-319-111' 'A-319-112' 'A-319-PSGR'
#  'A-320-1/2' 'A-320-112' 'A-320-114' 'A-320-214' 'A-320-214PSGR'
#  'A-320-2NEO' 'A-320-PSGR' 'A-320-PSGRNEO' 'A-321' 'A-321-231PSGR'
#  'A-321-PSGR' 'A220-100-PSGR' 'A220-300' 'A220-300-PSGR' 'A300-1/2'
#  'A300-6' 'A300-600' 'A300-600PASSENGER' 'A300-600RPASSENGER' 'A300B4-200'
#  'A300B4-605R' 'A300B4-622R' 'A300F4-605R' 'A300F4-622R' 'A300X4'
#  'A310-2CF' 'A310-3' 'A310-300' 'A318' 'A318-1' 'A319' 'A319-1' 'A319-111'
#  'A319-112' 'A319-114' 'A319-114-PSGR' 'A319-115' 'A319-115PASSENGER'
#  'A319-131' 'A319-132' 'A319-PSGR' 'A319PAX' 'A320' 'A320-1/2' 'A320-211'
#  'A320-211-PSGR' 'A320-212' 'A320-212-PSGR' 'A320-214' 'A320-231'
#  'A320-232' 'A320-232-PSGR' 'A320-271N' 'A320-PSGR' 'A320PAX' 'A321'
#  'A321-200NEO' 'A321-200NEO-PSGR' 'A321-211' 'A321-211-PSGR' 'A321-213'
#  'A321-231' 'A321-231(P2F)' 'A321-231(PCF)' 'A321-231-PSGR'
#  'A321-231PASSENGER' 'A321-232(PCF)' 'A321-253NX' 'A321-271N' 'A321-271NX'
#  'A3210200NEO' 'A321NEO' 'A321PAX' 'A330' 'A330-2' 'A330-200' 'A330-223'
#  'A330-223-PSGR' 'A330-243' 'A330-3' 'A330-300' 'A330-302' 'A330-302-PSGR'
#  'A330-323' 'A330-323-PSGR' 'A330-323X' 'A330-343' 'A330-941'
#  'A330-941-PSGR' 'A330-PSGR' 'A3300200' 'A350-900-PSGR' 'A350-941'
#  'A350-941-PSGR' 'AIRBUSA319-131' 'AIRBUSA319-131PAX' 'AIRBUSA320-232'
#  'AIRBUSA320-232PAX' 'ATR-42' 'ATR-42-300' 'ATR-72' 'ATR-72-212'
#  'ATR-72-212A' 'ATR-72PASSENGER' 'ATR42-300' 'ATR42-320' 'ATR42-500'
#  'ATR42-500PSGR' 'ATR72' 'ATR72-212' 'ATR72-212A' 'ATR72-500PRTR'
#  'ATR72-500PSGR' 'ATR72-600F' 'ATR72202' 'AW-139' 'AW139PSGR' 'B-1900'
#  'B-206A' 'B-717-2' 'B-717-200' 'B-727-2' 'B-727-200' 'B-727-223'
#  'B-727-224' 'B-727-225' 'B-727-264' 'B-727-2B6' 'B-727-2H3' 'B-727-2M7'
#  'B-732-AF' 'B-737-1/2' 'B-737-1/2CRG' 'B-737-282C' 'B-737-290C'
#  'B-737-2C' 'B-737-2X6C' 'B-737-3' 'B-737-300' 'B-737-300-PSGR'
#  'B-737-300CRG' 'B-737-301' 'B-737-3A4' 'B-737-3G7' 'B-737-3H4'
#  'B-737-3K2' 'B-737-3L9' 'B-737-3Q8' 'B-737-3T0' 'B-737-3T5' 'B-737-3Y0'
#  'B-737-4' 'B-737-400' 'B-737-400-PSGR' 'B-737-400PSGR' 'B-737-401'
#  'B-737-45D' 'B-737-4B7' 'B-737-4PSGR' 'B-737-500' 'B-737-5H4' 'B-737-7'
#  'B-737-700' 'B-737-700-PSGR' 'B-737-705' 'B-737-71B' 'B-737-73V'
#  'B-737-752' 'B-737-752-PSGR' 'B-737-76N' 'B-737-76Q' 'B-737-790'
#  'B-737-79L' 'B-737-79P' 'B-737-7AD' 'B-737-7BD' 'B-737-7BK' 'B-737-7BX'
#  'B-737-7CT' 'B-737-7H4' 'B-737-7H4-PSGR' 'B-737-7HJ' 'B-737-7K5'
#  'B-737-7K9' 'B-737-7L' 'B-737-7L9' 'B-737-7Q8' 'B-737-8' 'B-737-800'
#  'B-737-800-PSGR' 'B-737-800PSGR' 'B-737-86N-PSGR' 'B-737-8EH-PSGR'
#  'B-737-8F2-PSGR' 'B-737-8H4' 'B-737-8MAX' 'B-737-9' 'B-747' 'B-747-1'
#  'B-747-222B' 'B-747-246F' 'B-747-251B' 'B-747-4' 'B-747-400'
#  'B-747-400CRG' 'B-747-412F' 'B-747-412SF' 'B-747-428F' 'B-747-446'
#  'B-747-4H6' 'B-747-4R7F' 'B-747F' 'B-757-2' 'B-757-200' 'B-757-3'
#  'B-757CARGO' 'B-767-2' 'B-767-2-PSGR' 'B-767-200' 'B-767-201'
#  'B-767-224ERPAX' 'B-767-232SF' 'B-767-233' 'B-767-233PSGR' 'B-767-238'
#  'B-767-238PSGR' 'B-767-23BPSGR' 'B-767-246' 'B-767-246PSGR'
#  'B-767-266PSGR' 'B-767-2R-PSGR' 'B-767-3' 'B-767-300' 'B-767-300ERPAX'
#  'B-767-300PAX' 'B-767-300SF' 'B-767-319ERPAX' 'B-767-336' 'B-767-336PSGR'
#  'B-767-33AERPAX' 'B-767-3S2F' 'B-767-PSGR' 'B-777-2' 'B-777-212'
#  'B-777-222ERPAX' 'B-777-2U8' 'B-777-388PSGR' 'B-777-F' 'B-777-F28'
#  'B-777-FHT' 'B-777-FS2' 'B-IV-450PSGR' 'B717-2' 'B717-200'
#  'B717-200-PSGR' 'B7170200' 'B727-1' 'B727-100' 'B727-2' 'B727-200'
#  'B727-CARGO' 'B737-1/2' 'B737-100/200PSGR' 'B737-232' 'B737-282C'
#  'B737-2C' 'B737-3' 'B737-300' 'B737-300-PSGR' 'B737-300PAX' 'B737-301'
#  'B737-301(SF)' 'B737-319' 'B737-319(SF)' 'B737-330' 'B737-330(SF)'
#  'B737-3B7' 'B737-3G7' 'B737-3Q8(QC)' 'B737-3S3' 'B737-3Y0' 'B737-4'
#  'B737-400-PSGR' 'B737-400PSGR' 'B737-401' 'B737-436' 'B737-436(SF)'
#  'B737-490ALLPAX' 'B737-490CARGO' 'B737-490COMBI' 'B737-4B7'
#  'B737-4Q8ALLPAX' 'B737-4Q8COMBI' 'B737-4S3ALLPAX' 'B737-5' 'B737-500'
#  'B737-500PAX' 'B737-7' 'B737-7/L' 'B737-700' 'B737-700(BBJ1)'
#  'B737-700-PSGR' 'B737-700PAX' 'B737-790' 'B737-790ALLCARGO'
#  'B737-790ALLPAX' 'B737-8' 'B737-800' 'B737-800BCF' 'B737-800MAX'
#  'B737-800PAX' 'B737-823' 'B737-823PASSENGER' 'B737-890ALLCARGO'
#  'B737-890ALLPAX' 'B737-9' 'B737-900ER' 'B737-900ERPAX' 'B737-900PAX'
#  'B737-990ALLPAX' 'B737-990ERALLPAX' 'B737-MAX800ALLPAX' 'B737-MAX8PAX'
#  'B737-MAX900ALLPAX' 'B737-MAX9PAX' 'B737-PSGR' 'B737PASSENGER' 'B744-F'
#  'B747-1' 'B747-2/3' 'B747-200' 'B747-300' 'B747-4' 'B747-400'
#  'B747-400BCF' 'B747-400CARGO' 'B747-422PAX' 'B747-446' 'B747-46NF'
#  'B747-47UF' 'B747-481' 'B747-48E' 'B747-4F' 'B747-800' 'B747-87UF'
#  'B747-F' 'B757' 'B757-2' 'B757-200' 'B757-200ER' 'B757-200PASSENGER'
#  'B757-200PAX' 'B757-200PSGR' 'B757-222PAX' 'B757-223' 'B757-223ER'
#  'B757-223PASSENGER' 'B757-23N' 'B757-28A' 'B757-2B7' 'B757-2G7'
#  'B757-2S7' 'B757-3' 'B757-300PAX' 'B757-CARGO' 'B767-2' 'B767-2-PSGR'
#  'B767-2/R' 'B767-200' 'B767-200-ERSF' 'B767-200PAX' 'B767-201ER'
#  'B767-223ER' 'B767-223ERPASSENGER' 'B767-223SF' 'B767-224' 'B767-224ER'
#  'B767-231' 'B767-232SF' 'B767-241' 'B767-281SF' 'B767-2B7ER'
#  'B767-2R-PSGR' 'B767-3' 'B767-300' 'B767-300ER' 'B767-300F'
#  'B767-300PSGR' 'B767-300SF' 'B767-316' 'B767-316F' 'B767-319ER'
#  'B767-322DRPAX' 'B767-322ERPAX' 'B767-323' 'B767-323(ER)(BDSF)'
#  'B767-323ER' 'B767-323ERPASSENGER' 'B767-328' 'B767-328ER' 'B767-332'
#  'B767-33AER' 'B767-341BDSF' 'B767-346F' 'B767-38FG' 'B767-3CBER'
#  'B767-3G5ER' 'B767-3P6' 'B767-3Q8' 'B767-4' 'B767-400' 'B767-400PAX'
#  'B777-2' 'B777-200' 'B777-200PASSENGER' 'B777-200PAX' 'B777-222BPAX'
#  'B777-222ER' 'B777-222PAX' 'B777-223ER' 'B777-223ERPASSENGER' 'B777-300'
#  'B777-300ER' 'B777-300ERPAX' 'B777-300PASSENGER' 'B777-F' 'B787-10PAX'
#  'B787-8' 'B787-800PAX' 'B787-9' 'B787-900PAX' 'BAE-31' 'BBJ-737-7EG'
#  'BBJ737-7EG' 'BBJ7377EG' 'BD-100-1A10' 'BD-100-1A10PSGR' 'BD-500-1A10'
#  'BD-500-1A11' 'BD-700' 'BD-700-1A10' 'BD-700-1A10GLOBAL600'
#  'BD-700-1A10GLOBAL650' 'BD-700-1A10PSGR' 'BD-700-1A11' 'BD-700-1A11PSGR'
#  'BD-700-2A12' 'BD-700GLOBALEXPRESS' 'BE-1900' 'BOEING717-200'
#  'BOEING717-23S' 'BOEING717-2BD' 'BOEING737-45D' 'BOEING737-4K5'
#  'BOEING737-700/LR' 'BOEING737-883' 'BOEING757-200' 'BOEING767-200/ER'
#  'BOEING767-300/ER' 'BOEINGB-737-76N' 'BOEINGB-737-7BD' 'BOEINGB-737-7HJ'
#  'BOEINGB767-224ERPAX' 'BOEINGB767-300ERPAX' 'BOEINGB767-316ERPAX'
#  'BOEINGB767-319ERPAX' 'BOEINGB767-323ERPAX' 'BOEINGB767-324ERPAX'
#  'BOEINGB767-33AERPAX' 'BOEINGB767-36NERPAX' 'BOEINGB767-3Q8ERPAX'
#  'BOEINGB777-222ERPAX' 'BOMBARDIER' 'C-118A' 'C-118ACARGO' 'C-11ACARGO'
#  'C-206PASS' 'C-208' 'C-208A' 'C-208B' 'C-208B/3' 'C-208BCOMBI' 'C-46/20T'
#  'C-46D' 'C-46DCARGO' 'C-46FCARGO' 'C-46RCARGO' 'C-AT-210N' 'C340/335'
#  'CE-206/7' 'CE-208B' 'CE-340' 'CE-560-560XLS' 'CE-560-560XLSPSGR'
#  'CE-560XL' 'CE-680' 'CE-680A' 'CE-750-750PSGR' 'CE-750X' 'CES-180ECOMBI'
#  'CES-206H' 'CESSNA510/560XL' 'CESSNAT-210N' 'CHAL-300' 'CHAL-350'
#  'CHAL-601-3A' 'CHAL300' 'CHAL601' 'CHAL604' 'CHAL605' 'CHALL604'
#  'CHALLENGER300' 'CHALLENGER601' 'CHALLENGER6011A' 'CHALLENGER604'
#  'CHALLENGER605' 'CHEROKEE' 'CITATION' 'CITATIONBRAVO' 'CITATIONX'
#  'CITATIONXLS' 'CITATNJ' 'CJ3' 'CL-600' 'CL-600-2B19' 'CL-600-2B19-PSGR'
#  'CL-600-2C10' 'CL-600-2C11' 'CL-600-2D24' 'CL-604' 'CL-605' 'CL600-2010'
#  'CL600-2B19' 'CL600-2B19-PSGR' 'CL600-2B19PSGR' 'CL600-2C10'
#  'CL600-2C10PSGR' 'CL600-2C15' 'CL600-2D24' 'CL6002B16-605' 'CL65'
#  'CN235-200' 'CN235-300' 'COMMANDO' 'CRJ-100LR-PSGR' 'CRJ-2/4' 'CRJ-200'
#  'CRJ-200-2B19' 'CRJ-200-PSGR' 'CRJ-200/440' 'CRJ-200LR-PSGR' 'CRJ-400'
#  'CRJ-550-PSGR' 'CRJ-700' 'CRJ-700-2C10' 'CRJ-700-PSGR' 'CRJ-700LR-PSGR'
#  'CRJ-700PASSENGER' 'CRJ-701' 'CRJ-70C' 'CRJ-900' 'CRJ-900-2D24'
#  'CRJ-900-PSGR' 'CRJ-900LR-PSGR' 'CRJ100-PASSANGER' 'CRJ100-PSGR' 'CRJ200'
#  'CRJ200-2B10' 'CRJ200-2B19' 'CRJ200-PASSANGER' 'CRJ200LR' 'CRJ550'
#  'CRJ700' 'CRJ700-2C10' 'CRJ700-PASSANGER' 'CRJ701' 'CRJ70C' 'CRJ900'
#  'CRJ900-2D10' 'CRJ900-2D24' 'CRJ900-PASSANGER' 'CRJ90C' 'CV-580'
#  'CV-580-CARGO' 'CV340-CARGO' 'CV440-CARGO' 'CV580-CARGO' 'CV5800-CARGO'
#  'CV640CARGO' 'DASH8-1' 'DASH8-Q4' 'DASSAULT-FALCON-2000'
#  'DASSAULT-FALCON-50EX' 'DASSAULT-FALCON-50PS' 'DASSAULT-FALCON-7X'
#  'DASSAULT-FALCON-7XPS' 'DASSAULT-FALCON-900E' 'DASSAULT-FALCON-900L'
#  'DC-10-1' 'DC-10-10' 'DC-10-3' 'DC-10-30' 'DC-10-4' 'DC-10-F' 'DC-6A'
#  'DC-6ACARGO' 'DC-6B' 'DC-6BCARGO' 'DC-6BST' 'DC-8-62' 'DC-8-6F' 'DC-8-71'
#  'DC-8-72' 'DC-8-73' 'DC-8-73F' 'DC-8/62CARGO' 'DC-8/62COMBI'
#  'DC-8/71CARGO' 'DC-8/72COMBI' 'DC-8/73CARGO' 'DC-9-10' 'DC-9-15'
#  'DC-9-15F' 'DC-9-30' 'DC-9-32F' 'DC-9-32FCARGO' 'DC-9-33CARGO' 'DC-9-33F'
#  'DC-9-33FCARGO' 'DC-9-34' 'DC-9-40' 'DC-9-41FCARGO' 'DC-9-50'
#  'DC-9-80ALLPAX' 'DC-9-82' 'DC-9-82(MD82)' 'DC-9-82CARGO' 'DC-9-83'
#  'DC-9-83(MD-83)']

# %%
# AIRCRAFT_STATUS

print(aircraft_copy['AIRCRAFT_STATUS'].value_counts())

# From the website, there is only A, B, and O. I am going to convert the lowercase letters into uppercase.
aircraft_copy['AIRCRAFT_STATUS'] = aircraft_copy['AIRCRAFT_STATUS'].str.upper()

print(aircraft_copy['AIRCRAFT_STATUS'].value_counts())

# Inspecting the values with AIRCRAFT_STATUS L
aircraft_copy[aircraft_copy['AIRCRAFT_STATUS'] == 'L']

united_rows = aircraft[aircraft['CARRIER_NAME'].str.upper().str.strip() == 'UNITED AIR LINES INC.']
print(united_rows.drop_duplicates().sort_values(
    'AIRCRAFT_STATUS'
))
# print(united_rows[['YEAR', 'CARRIER', 'CARRIER_NAME', 'AIRCRAFT_STATUS', 'OPERATING_STATUS']].drop_duplicates())
# United Air Lines Inc. uses O, B, and A, so I'm not sure what L is referring to.
# Out:
# AIRCRAFT_STATUS
# O    79487
# b    30852
# B    12699
# a     7804
# A     1330
# L      122
# o       19
# Name: count, dtype: int64
# AIRCRAFT_STATUS
# O    79506
# B    43551
# A     9134
# L      122
# Name: count, dtype: int64
#         YEAR CARRIER           CARRIER_NAME  MANUFACTURE_YEAR  \
# 27334   2009     UA   United Air Lines Inc.            1991.0
# 20519   2008      UA  United Air Lines Inc.            1999.0
# 20518   2008      UA  United Air Lines Inc.            1999.0
# 20512   2008      UA  United Air Lines Inc.            1999.0
# 5940    2006      UA  United Air Lines Inc.            2000.0
# ...      ...     ...                    ...               ...
# 48546   2012      UA  United Air Lines Inc.            1995.0
# 130548  2023      UA  United Air Lines Inc.            2004.0
# 130549  2023      UA  United Air Lines Inc.            2004.0
# 55683   2013      UA  United Air Lines Inc.            2000.0
# 48794   2012      UA  United Air Lines Inc.            2000.0
#
#           UNIQUE_CARRIER_NAME    SERIAL_NUMBER      TAIL_NUMBER  \
# 27334   United Air Lines Inc.  25130            N535UA
# 20519   United Air Lines Inc.              948           N822UA
# 20518   United Air Lines Inc.              944           N821UA
# 20512   United Air Lines Inc.            30024           N668UA
# 5940    United Air Lines Inc.             1248           N460UA
# ...                       ...              ...              ...
# 48546   United Air Lines Inc.            27532           N14628
# 130548  United Air Lines Inc.            33452           N78285
# 130549  United Air Lines Inc.            33454           N73291
# 55683   United Air Lines Inc.            28678           N27015
# 48794   United Air Lines Inc.             1248           N460UA
#
#        AIRCRAFT_STATUS OPERATING_STATUS  NUMBER_OF_SEATS  \
# 27334                A                Y            182.0
# 20519                A                Y            120.0
# 20518                A                Y            120.0
# 20512                A                Y            219.0
# 5940                 A                Y            138.0
# ...                ...              ...              ...
# 48546                b                Y            114.0
# 130548               b                Y            154.0
# 130549               b                Y            154.0
# 55683                b                Y            276.0
# 48794                b                Y            142.0
#
#                                              MANUFACTURER AIRCRAFT_TYPE  \
# 27334   BOEING                                        ...           NaN
# 20519                                              AIRBUS           NaN
# 20518                                              AIRBUS           NaN
# 20512                                              BOEING           NaN
# 5940                                               AIRBUS           NaN
# ...                                                   ...           ...
# 48546                                            BoeingCo          6161
# 130548                                           BoeingCo          6141
# 130549                                           BoeingCo          6141
# 55683                                            BoeingCo          6271
# 48794                                    AirbusIndustries          6941
#
#                        MODEL  CAPACITY_IN_POUNDS        ACQUISITION_DATE  \
# 27334   B-757-2                          48990.0   6/12/1991 12:00:00 AM
# 20519                   A319             35930.0    2/2/1999 12:00:00 AM
# 20518                   A319             35930.0   1/21/1999 12:00:00 AM
# 20512                 B767-3             75445.0   3/15/1999 12:00:00 AM
# 5940                A320-1/2             35930.0   6/26/2000 12:00:00 AM
# ...                      ...                 ...                     ...
# 48546            B737-500PAX            129500.0   4/18/1995 12:00:00 AM
# 130548               737-824            174200.0    8/1/2015 12:00:00 AM
# 130549               737-824            174200.0    8/1/2017 12:00:00 AM
# 55683            B777-200PAX            656000.0    4/7/2000 12:00:00 AM
# 48794      AirbusA320-232PAX            169700.0  12/19/2000 12:00:00 AM
#
#         AIRLINE_ID UNIQUE_CARRIER
# 27334      19977.0             UA
# 20519      19977.0             UA
# 20518      19977.0             UA
# 20512      19977.0             UA
# 5940       19977.0             UA
# ...            ...            ...
# 48546      19977.0             UA
# 130548     19977.0             UA
# 130549     19977.0             UA
# 55683      19977.0             UA
# 48794      19977.0             UA
#
# [11984 rows x 17 columns]

# %%
# OPERATING_STATUS

print(aircraft_copy['OPERATING_STATUS'].value_counts())

# Converting all to uppercase to match the expected from the database
aircraft_copy['OPERATING_STATUS'] = aircraft_copy['OPERATING_STATUS'].astype(str).str.strip().str.upper()

# Checking
print(aircraft_copy['OPERATING_STATUS'].value_counts())

blank = aircraft_copy[aircraft_copy['OPERATING_STATUS'] == '']
print(blank)

# Finding similar aircrafts to the one with a missing operating status
similar_aircrafts = aircraft_copy[
    (aircraft_copy['MANUFACTURER'] == 'EMBRAER') &
    (aircraft_copy['AIRCRAFT_TYPE'] == 6751) &
    (aircraft_copy['AIRCRAFT_TYPE'] == 6751)
]

print(similar_aircrafts.shape[0])

# Number of Y for operating status for the similar aircrafts
num_Y = (similar_aircrafts['OPERATING_STATUS'] == 'Y').sum()
print(num_Y)

display(similar_aircrafts[similar_aircrafts['OPERATING_STATUS'] == 'N'])
display(blank)

# Since almost all of the similar aircrafts have an operating status of Y and those with N have a different aircraft status
# and a different capacity than the one with the missing operating status, I am assuming that the missing value should be a Y.

aircraft_copy.loc[aircraft_copy['OPERATING_STATUS'] == '', 'OPERATING_STATUS'] = 'Y'
# Out:
# OPERATING_STATUS
# Y    126577
# N      5664
# y        71
#           1
# Name: count, dtype: int64
# OPERATING_STATUS
# Y    126648
# N      5664
#           1
# Name: count, dtype: int64
#         YEAR CARRIER                   CARRIER_NAME  MANUFACTURE_YEAR  \
# 118601  2022      C5  CommuteAir LLC dba CommuteAir            2003.0
#
#                   UNIQUE_CARRIER_NAME SERIAL_NUMBER TAIL_NUMBER  \
# 118601  CommuteAir LLC dba CommuteAir        145700      N24128
#
#        AIRCRAFT_STATUS OPERATING_STATUS  NUMBER_OF_SEATS MANUFACTURER  \
# 118601               B                              50.0      EMBRAER
#
#        AIRCRAFT_TYPE      MODEL  CAPACITY_IN_POUNDS      ACQUISITION_DATE  \
# 118601          6751  EMB-145XR             12755.0  9/1/2020 12:00:00 AM
#
#         AIRLINE_ID UNIQUE_CARRIER
# 118601     20445.0             C5
# 3033
# 3029
#        YEAR CARRIER              CARRIER_NAME  MANUFACTURE_YEAR  \
# 62105  2014      RP  Chautauqua Airlines Inc.            2003.0
# 76622  2016      S5     Shuttle America Corp.            1999.0
# 76623  2016      S5     Shuttle America Corp.            2000.0
# 85653  2017      YX          Republic Airline            1999.0
#
#             UNIQUE_CARRIER_NAME SERIAL_NUMBER TAIL_NUMBER AIRCRAFT_STATUS  \
# 62105  Chautauqua Airlines Inc.        145426      N971RP               O
# 76622     Shuttle America Corp.        145128      N260SK               O
# 76623     Shuttle America Corp.        145221      N264SK               O
# 85653          Republic Airline        145128      N260SK               O
#
#       OPERATING_STATUS  NUMBER_OF_SEATS MANUFACTURER AIRCRAFT_TYPE      MODEL  \
# 62105                N             50.0      EMBRAER          6751  EMB-145LR
# 76622                N             50.0      EMBRAER          6751   ERJ145LR
# 76623                N             50.0      EMBRAER          6751   ERJ145LR
# 85653                N             50.0      EMBRAER          6751  ERJ-145LR
#
#        CAPACITY_IN_POUNDS       ACQUISITION_DATE  AIRLINE_ID UNIQUE_CARRIER
# 62105             48501.0  3/20/2003 12:00:00 AM     20418.0             RP
# 76622             48501.0  4/30/1999 12:00:00 AM     20448.0             S5
# 76623             48501.0  1/31/2000 12:00:00 AM     20448.0             S5
# 85653             48501.0  4/30/1999 12:00:00 AM     20452.0             YX
#         YEAR CARRIER                   CARRIER_NAME  MANUFACTURE_YEAR  \
# 118601  2022      C5  CommuteAir LLC dba CommuteAir            2003.0
#
#                   UNIQUE_CARRIER_NAME SERIAL_NUMBER TAIL_NUMBER  \
# 118601  CommuteAir LLC dba CommuteAir        145700      N24128
#
#        AIRCRAFT_STATUS OPERATING_STATUS  NUMBER_OF_SEATS MANUFACTURER  \
# 118601               B                              50.0      EMBRAER
#
#        AIRCRAFT_TYPE      MODEL  CAPACITY_IN_POUNDS      ACQUISITION_DATE  \
# 118601          6751  EMB-145XR             12755.0  9/1/2020 12:00:00 AM
#
#         AIRLINE_ID UNIQUE_CARRIER
# 118601     20445.0             C5

# %% [markdown]
# **Question 3**

# %%
# Dropping the remaining rows with missing values
aircraft_cleaned = aircraft_copy.dropna()
print("Remaining rows after dropping missing values:", aircraft_cleaned.shape[0])
# Out:
# Remaining rows after dropping missing values: 101276

# %% [markdown]
# **Question 4**

# %%
print("Skewness for NUMBER_OF_SEATS:", aircraft_cleaned['NUMBER_OF_SEATS'].skew())
print("Skewness for CAPACITY_IN_POUNDS:", aircraft_cleaned['CAPACITY_IN_POUNDS'].skew())

# Plotting histograms
fig, axes = plt.subplots(2, 1, figsize=(10, 10))
sns.histplot(aircraft_cleaned['NUMBER_OF_SEATS'], bins = 30, ax=axes[0])
axes[0].set_title('Histogram of NUMBER_OF_SEATS (Before Box-Cox)')
sns.histplot(aircraft_cleaned['CAPACITY_IN_POUNDS'], bins = 30, ax=axes[1])
axes[1].set_title('Histogram of CAPACITY_IN_POUNDS (Before Box-Cox)')
plt.tight_layout()
plt.show()
# Out:
# Skewness for NUMBER_OF_SEATS: 0.3783679535650706
# Skewness for CAPACITY_IN_POUNDS: 3.7598348593236057

# %%
from scipy.stats import boxcox

# Data must be positive for boxcox
seats_positive = aircraft_cleaned['NUMBER_OF_SEATS'][aircraft_cleaned['NUMBER_OF_SEATS'] > 0]
capacity_positive = aircraft_cleaned['CAPACITY_IN_POUNDS'][aircraft_cleaned['CAPACITY_IN_POUNDS'] > 0]

# Boxcox
seats_boxcox, _ = boxcox(seats_positive)
capacity_boxcox, _ = boxcox(capacity_positive)

# Storing values
aircraft_cleaned.loc[seats_positive.index, 'NUMBER_OF_SEATS_BOXCOX'] = seats_boxcox
aircraft_cleaned.loc[capacity_positive.index, 'CAPACITY_IN_POUNDS_BOXCOX'] = capacity_boxcox

# Plotting histograms for the transformed variables
fig, axes = plt.subplots(2, 1, figsize=(10, 10))
sns.histplot(aircraft_cleaned['NUMBER_OF_SEATS_BOXCOX'], bins = 30, ax=axes[0])
axes[0].set_title('Histogram of NUMBER_OF_SEATS (Box-Cox)')
sns.histplot(aircraft_cleaned['CAPACITY_IN_POUNDS_BOXCOX'], bins = 30, ax=axes[1])
axes[1].set_title('Histogram of CAPACITY_IN_POUNDS (Box-Cox)')
plt.tight_layout()
plt.show()

# Before the Box-Cox transformation, the data was very skewed, especially for the CAPACITY_IN_POUNDS plot,
# which was also depicted by the skewness value. Both plots were  skewed to the right before transformation.
# After the transformation, the distributions look much closer to normal and are centered around similar values.
# Out:
# <ipython-input-446-62e9f8adbba4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aircraft_cleaned.loc[seats_positive.index, 'NUMBER_OF_SEATS_BOXCOX'] = seats_boxcox
# <ipython-input-446-62e9f8adbba4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aircraft_cleaned.loc[capacity_positive.index, 'CAPACITY_IN_POUNDS_BOXCOX'] = capacity_boxcox

# %% [markdown]
# **Question 5**

# %%
q1 = aircraft_cleaned['NUMBER_OF_SEATS'].quantile(0.25)
q2 = aircraft_cleaned['NUMBER_OF_SEATS'].quantile(0.50)
q3 = aircraft_cleaned['NUMBER_OF_SEATS'].quantile(0.75)

aircraft_cleaned['SIZE'] = 'NA'

# Apply conditions
aircraft_cleaned.loc[aircraft_cleaned['NUMBER_OF_SEATS'] < q1, 'SIZE'] = 'SMALL'
aircraft_cleaned.loc[(aircraft_cleaned['NUMBER_OF_SEATS'] >= q1) & (aircraft_cleaned['NUMBER_OF_SEATS'] < q2), 'SIZE'] = 'MEDIUM'
aircraft_cleaned.loc[(aircraft_cleaned['NUMBER_OF_SEATS'] >= q2) & (aircraft_cleaned['NUMBER_OF_SEATS'] < q3), 'SIZE'] = 'LARGE'
aircraft_cleaned.loc[aircraft_cleaned['NUMBER_OF_SEATS'] >= q3, 'SIZE'] = 'XLARGE'
# Out:
# <ipython-input-459-d606297b69ef>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aircraft_cleaned['SIZE'] = 'NA'

# %%
# OPERATING_STATUS
# Calculating proportion of aircrafts
total_small = len(aircraft_cleaned[aircraft_cleaned['SIZE'] == 'SMALL'])
total_medium = len(aircraft_cleaned[aircraft_cleaned['SIZE'] == 'MEDIUM'])
total_large = len(aircraft_cleaned[aircraft_cleaned['SIZE'] == 'LARGE'])
total_xlarge = len(aircraft_cleaned[aircraft_cleaned['SIZE'] == 'XLARGE'])

# Number of aircrafts that are operating
y_small = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'SMALL') & (aircraft_cleaned['OPERATING_STATUS'] == 'Y')])
y_medium = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'MEDIUM') & (aircraft_cleaned['OPERATING_STATUS'] == 'Y')])
y_large = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'LARGE') & (aircraft_cleaned['OPERATING_STATUS'] == 'Y')])
y_xlarge = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'XLARGE') & (aircraft_cleaned['OPERATING_STATUS'] == 'Y')])


print("SMALL:", y_small / total_small)
print("MEDIUM:", y_medium / total_medium)
print("LARGE:", y_large / total_large)
print("XLARGE:", y_xlarge / total_xlarge)
# Out:
# SMALL: 0.9691650129751183
# MEDIUM: 0.9476290661919404
# LARGE: 0.966714048803601
# XLARGE: 0.9694118573340682

# %%
# Easier to visualize seeing against the total vs plotting proportions direction

total_vals = [total_small, total_medium, total_large, total_xlarge]
operating_vals = [y_small, y_medium, y_large, y_xlarge]

not_operating_small = total_small - y_small
not_operating_medium = total_medium - y_medium
not_operating_large = total_large - y_large
not_operating_xlarge = total_xlarge - y_xlarge

not_operating_vals = [not_operating_small, not_operating_medium, not_operating_large, not_operating_xlarge]

# Plotting
fig, ax = plt.subplots(1, 1)
labels = ['SMALL', 'MEDIUM', 'LARGE', 'XLARGE']
x = list(range(len(labels)))
plt.bar(x, not_operating_vals, color='purple', label='Not Operating')
plt.bar(x, operating_vals, bottom=not_operating_vals, color='grey', label='Operating')
plt.xticks(x, labels)
plt.ylabel('Number of Aircrafts')
plt.title('Proportions of aircrafts that are operating by size group')
plt.legend()
plt.show()

# %%
import numpy as np
# AIRCRAFT_STATUS

# Number of aircrafts that are operating
# For 'A'
A_small = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'SMALL') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'A')])
A_medium = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'MEDIUM') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'A')])
A_large = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'LARGE') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'A')])
A_xlarge = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'XLARGE') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'A')])

# For 'B'
B_small = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'SMALL') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'B')])
B_medium = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'MEDIUM') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'B')])
B_large = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'LARGE') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'B')])
B_xlarge = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'XLARGE') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'B')])

# For 'O'
O_small = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'SMALL') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'O')])
O_medium = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'MEDIUM') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'O')])
O_large = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'LARGE') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'O')])
O_xlarge = len(aircraft_cleaned[(aircraft_cleaned['SIZE'] == 'XLARGE') & (aircraft_cleaned['AIRCRAFT_STATUS'] == 'O')])

# L???

labels = ['SMALL', 'MEDIUM', 'LARGE', 'XLARGE']
x = np.arange(len(labels))
A_vals = [A_small, A_medium, A_large, A_xlarge]
B_vals = [B_small, B_medium, B_large, B_xlarge]
O_vals = [O_small, O_medium, O_large, O_xlarge]

# Calculate bottom positions for stacking
bottom_AB = np.array(A_vals) + np.array(B_vals)

# Plotting
fig, ax = plt.subplots(1, 1)
labels = ['SMALL', 'MEDIUM', 'LARGE', 'XLARGE']
ax.bar(x, A_vals, label='A', color='lightgray')
ax.bar(x, B_vals, bottom=A_vals, label='B', color='darkgray')
ax.bar(x, O_vals, bottom=bottom_AB, label='O', color='purple')
ax.set_xlabel('Aircraft Size')
ax.set_ylabel('Number of Aircrafts')
ax.set_title('Proportions of Aircraft Status by Size Group')
plt.xticks(x, labels)
plt.legend()
plt.show()
